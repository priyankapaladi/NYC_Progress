# %% [markdown]
# # Statuses of various complaints!
# # Statuses of complaints wrt agency!

# %%
import pandas as pd
import numpy as np
from datetime import datetime,timedelta,date
import calendar

# %%
#statuses of various complaints

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)

dataframe3 = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull())].groupby(['Status', 'Complaint Type'])["Complaint Type"].count().reset_index(name="count")
dataframe3.sort_values(by='Status', ascending=0).reset_index(drop =True)
# Out:
#       Status                 Complaint Type  count
# 0    Pending                        Smoking      1
# 1    Pending                         Rodent      2
# 2    Pending                     Poison Ivy      1
# 3    Pending           Non-Residential Heat      2
# 4    Pending             Food Establishment      2
# 5       Open        Overgrown Tree/Branches      7
# 6       Open                 Food Poisoning      1
# 7       Open                Illegal Parking      2
# 8       Open            Illegal Tree Damage      1
# 9       Open             Indoor Air Quality      6
# 10      Open                      Dead Tree      2
# 11      Open  Root/Sewer/Sidewalk Condition      3
# 12      Open               Street Condition      1
# 13      Open                Taxi Compliment      1
# 14      Open                 Standing Water      1
# 15    Closed        Overgrown Tree/Branches      7
# 16    Closed  Root/Sewer/Sidewalk Condition      8
# 17    Closed                         Rodent      2
# 18    Closed      Public Payphone Complaint      1
# 19    Closed          Posting Advertisement      2
# 20    Closed                       PLUMBING      7
# 21    Closed                  PAINT/PLASTER     10
# 22    Closed                Noise - Vehicle     24
# 23    Closed              Open Flame Permit      1
# 24    Closed        Noise - Street/Sidewalk     94
# 25    Closed                   Noise - Park     11
# 26    Closed       Noise - House of Worship      1
# 27    Closed             Noise - Commercial     62
# 28    Closed           Sanitation Condition      1
# 29    Closed                          SCRIE      4
# ..       ...                            ...    ...
# 63    Closed       Benefit Card Replacement     20
# 64    Closed               Animal in a Park      3
# 65    Closed                   Animal Abuse     11
# 66    Closed                      APPLIANCE      2
# 67    Closed             Indoor Air Quality      5
# 68    Closed               Derelict Vehicle     22
# 69    Closed     For Hire Vehicle Complaint      5
# 70    Closed               Dirty Conditions      2
# 71    Closed            Homeless Encampment     15
# 72    Closed              Highway Condition      3
# 73    Closed         HPD Literature Request      1
# 74    Closed                 HEAT/HOT WATER     15
# 75    Closed                       Graffiti      1
# 76    Closed  General Construction/Plumbing      1
# 77    Closed                        GENERAL      1
# 78    Closed                 Food Poisoning      2
# 79    Closed            Illegal Tree Damage      2
# 80    Closed             Food Establishment     14
# 81    Closed     Fire Safety Director - F58      2
# 82    Closed                Ferry Complaint      1
# 83    Closed                FLOORING/STAIRS      5
# 84    Closed                       ELECTRIC      6
# 85    Closed           EAP Inspection - F59      1
# 86    Closed                       Drinking      5
# 87    Closed                Illegal Parking    140
# 88  Assigned                        Smoking      1
# 89  Assigned        Overgrown Tree/Branches      2
# 90  Assigned                      Dead Tree      2
# 91  Assigned                 Taxi Complaint      1
# 92  Assigned                   Damaged Tree      4
#
# [93 rows x 3 columns]

# %%
#statuses of various complaints wrt agencies and boroughs

# %%
dataframe3 = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull())].groupby(['Status', 'Agency','Borough'])["Agency"].count().reset_index(name="count")
dataframe3.sort_values(by='Status', ascending=0).reset_index(drop =True)
# Out:
#       Status Agency        Borough  count
# 0    Pending  DOHMH      MANHATTAN      3
# 1    Pending  DOHMH       BROOKLYN      2
# 2    Pending  DOHMH          BRONX      3
# 3       Open    DPR          BRONX      4
# 4       Open  DOHMH          BRONX      1
# 5       Open  DOHMH       BROOKLYN      3
# 6       Open  DOHMH         QUEENS      1
# 7       Open    DOT         QUEENS      1
# 8       Open  DOHMH      MANHATTAN      3
# 9       Open    DPR       BROOKLYN      4
# 10      Open    DPR         QUEENS      5
# 11      Open   NYPD    Unspecified      2
# 12      Open    TLC    Unspecified      1
# 13    Closed   NYPD          BRONX     88
# 14    Closed   FDNY          BRONX      1
# 15    Closed   FDNY      MANHATTAN      2
# 16    Closed   FDNY         QUEENS      1
# 17    Closed    HPD          BRONX     24
# 18    Closed    HPD       BROOKLYN     15
# 19    Closed    HPD      MANHATTAN     18
# 20    Closed    HPD         QUEENS      8
# 21    Closed    HPD    Unspecified      1
# 22    Closed    HRA    Unspecified     20
# 23    Closed    TLC       BROOKLYN      4
# 24    Closed   NYPD       BROOKLYN    206
# 25    Closed   NYPD      MANHATTAN    122
# 26    Closed   NYPD         QUEENS    126
# 27    Closed   NYPD  STATEN ISLAND     21
# 28    Closed   NYPD    Unspecified      1
# 29    Closed    TLC          BRONX      1
# ..       ...    ...            ...    ...
# 42    Closed    DCA  STATEN ISLAND      1
# 43    Closed    DCA    Unspecified      2
# 44    Closed    DOB       BROOKLYN      1
# 45    Closed    DOB         QUEENS     15
# 46    Closed    DOE       BROOKLYN      1
# 47    Closed    DOE      MANHATTAN      1
# 48    Closed    DOF      MANHATTAN      2
# 49    Closed    DOF         QUEENS      1
# 50    Closed    DOF  STATEN ISLAND      1
# 51    Closed    DPR  STATEN ISLAND     11
# 52    Closed  DOHMH       BROOKLYN      5
# 53    Closed  DOHMH      MANHATTAN     10
# 54    Closed  DOHMH         QUEENS      7
# 55    Closed  DOHMH  STATEN ISLAND      2
# 56    Closed  DOITT      MANHATTAN      1
# 57    Closed    DOT          BRONX     20
# 58    Closed    DOT       BROOKLYN     29
# 59    Closed    DOT      MANHATTAN     22
# 60    Closed    DOT         QUEENS     37
# 61    Closed    DOT  STATEN ISLAND      8
# 62    Closed    DOT    Unspecified      2
# 63    Closed    DPR          BRONX      5
# 64    Closed    DPR       BROOKLYN     14
# 65    Closed    DPR      MANHATTAN     12
# 66    Closed    DPR         QUEENS     29
# 67    Closed  3-1-1      MANHATTAN      1
# 68  Assigned    DPR         QUEENS      4
# 69  Assigned    DPR       BROOKLYN      4
# 70  Assigned    TLC       BROOKLYN      1
# 71  Assigned  DOHMH         QUEENS      1
#
# [72 rows x 4 columns]

# %%
# group wrt agencies and boroughs
# enter borough
borough_input = input("Please enter borough: ")
if borough_input == "":
    print("Please enter borough")
else:
    borough = borough_input.upper()
    dataframe3 = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull()) & (dataframe2['Borough'].str.contains(borough))].groupby(['Status', 'Agency'])["Agency"].count().reset_index(name="count")
    dataframe3.sort_values(by='Status', ascending=0).reset_index(drop =True)
dataframe3
# Out:
# Please enter borough:
# Please enter borough
#       Status Agency  count
# 0   Assigned    DPR      4
# 1   Assigned    TLC      1
# 2     Closed    DCA      6
# 3     Closed    DOB      1
# 4     Closed    DOE      1
# 5     Closed  DOHMH      5
# 6     Closed    DOT     29
# 7     Closed    DPR     14
# 8     Closed   DSNY      2
# 9     Closed    HPD     15
# 10    Closed   NYPD    206
# 11    Closed    TLC      4
# 12      Open  DOHMH      3
# 13      Open    DPR      4
# 14   Pending  DOHMH      2

# %%
# enter borough
boroughip = input("Please enter borough: ")
if boroughip == "":
    print("No borough entered")
    dataframe_all_borough = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull())].groupby(['Status', 'Borough'])["Status"].count().reset_index(name="count")
    plot_borough_status()
else:
    boroughip = boroughip.upper()
    dataframe_borough = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull()) & (dataframe2['Borough'].str.contains(borough))].groupby(['Status', 'Borough'])["Status"].count().reset_index(name="count")
    dataframe_borough = dataframe_borough.sort_values(by='Status', ascending=0).reset_index(drop =True)
    plot_borough_all()
dataframe_borough
# Out:
# Please enter borough: brooklyn
# C:\Users\Priyanka\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
#      Status   Borough  count
# 0   Pending  BROOKLYN      2
# 1      Open  BROOKLYN      7
# 2    Closed  BROOKLYN    283
# 3  Assigned  BROOKLYN      5

# %%
# %matplotlib inline
# import matplotlib.pyplot as plt
# import seaborn as sns
# cm = plt.cm.get_cmap('RdYlBu_r')

# dfall.plot.hist(alpha=0.5)
# plt.xlabel("weightage - (Quick in closing the issue)")
# plt.ylabel("Complaint Types")
# plt.suptitle(" Inefficiency of the agencies wrt to complaints (Inefficient Agencies)", y=1.2, fontsize=24)
# plt.title("Based on NYC 311 reuqests for the year 2015",y=1.1, fontsize=18)
# plt.savefig("F:/Python_Project/Analysis4/Images/inefficient_agencies.png", bbox_inches='tight')


def plot_borough_status():
    dfall = dataframe_all_borough.pivot(index='Status', columns='Borough', values='count')
    dfall

    dfall = dfall.fillna(0)
    dfall

    # %matplotlib inline
    import matplotlib.pyplot as plt
    import seaborn as sns

    #plt.figure(figsize=(25,8))
    dfp = dfall.cumsum()
    plt.figure(figsize=(15,15))
    dfall.plot()
    sns.set_style("whitegrid")
    sns.set_context("notebook", font_scale=2)
    #sns.barplot(x="Borough", y="count", hue="Status", data=dataframe_all_borough)
    plt.xlabel("Borough")
    plt.ylabel("Count of complaints with their statuses")
    plt.legend(loc= 'upper left', bbox_to_anchor=(1, 1))

    plt.suptitle("Complaints and their statuses", y=1.3, fontsize=24)
    plt.title("Based on NYC 311 reuqests for the year 2015",y=1.2, fontsize=18)
    plt.xticks(rotation=50)
    plt.savefig("F:/Python_Project/Analysis5/Images/"+boroughip+"complaints_statuses.png", bbox_inches='tight')

# %%
def plot_borough_all():
    # %matplotlib inline
    import matplotlib.pyplot as plt
    import seaborn as sns

    plt.figure(figsize=(25,8))
    sns.set_style("whitegrid")
    sns.set_context("notebook", font_scale=2)
    sns.barplot(x="Status", y="count", data=dataframe_borough)
    plt.xlabel("Borough")
    plt.ylabel("Count of complaints with their statuses")
    plt.legend(loc= 'upper left', bbox_to_anchor=(1, 1))

    plt.suptitle("Complaints and their statuses for "+ borough, y=1.3, fontsize=24)
    plt.title("Based on NYC 311 reuqests for the year 2015",y=1.2, fontsize=18)
    plt.xticks(rotation=50)
    plt.savefig("F:/Python_Project/Analysis5/Images/"+" complaints_statuses.png", bbox_inches='tight')
