# %% [markdown]
# # Query 2: Output should contain-
# # Column 1: List of complaints ordered by which one took the longest to get solved.
# # Column 2: Which agency was responsible for it

# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)

dataframe2['Created Date'] = pd.to_datetime(dataframe2['Created Date'])
dataframe2['Closed Date'] = pd.to_datetime(dataframe2['Closed Date'])

dataframe2['time'] = dataframe2['Closed Date'] - dataframe2['Created Date']



dataframe3 = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Complaint Type'] == "Food Establishment") & dataframe2['Closed Date'].notnull()]
#dataframe3 = dataframe2[dataframe2['Agency'].notnull() & dataframe2['Closed Date'].notnull()]

dataframe3['Time'] = dataframe3['Closed Date'] - dataframe3['Created Date']

dataframe3 = dataframe3[['Agency', 'Created Date', 'Complaint Type', 'Time', 'Borough']].sort_values(by='Time', ascending=0)
dataframe3
# Out:
# C:\Users\Priyanka\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     Agency        Created Date                 Complaint Type  \
# 679    DOB 2015-07-16 09:42:04  General Construction/Plumbing
# 705    DOT 2015-04-22 15:24:35               Street Condition
# 15     DOT 2015-04-28 17:54:46               Street Condition
# 690    DOT 2015-05-02 11:06:06               Street Condition
# 929    DOT 2015-05-11 19:03:56               Street Condition
#
#                  Time   Borough
# 679 381 days 14:17:56  BROOKLYN
# 705 169 days 01:05:34    QUEENS
# 15  162 days 22:36:11    QUEENS
# 690 159 days 05:25:23    QUEENS
# 929 149 days 21:28:59    QUEENS

# %% [markdown]
# # Query 3: Output should contain-
# # Column 1: List of Agencies
# # Column 3: Number of solved complaints.
# # Column 2: Their respective number of pending complaints(blank value in resolution action update column)

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)

dataframe3 = dataframe2[dataframe2['Agency'].notnull() & (dataframe2['Status'].notnull())].groupby(['Status', 'Agency'])["Borough"].count().reset_index(name="count")
dataframe3.sort_values(by='Status', ascending=0)
# Out:
#       Status Agency  count
# 23   Pending  DOHMH      8
# 22      Open    TLC      1
# 21      Open   NYPD      2
# 20      Open    DPR     13
# 19      Open    DOT      1
# 18      Open  DOHMH      8
# 13    Closed   FDNY      4
# 17    Closed    TLC     22
# 16    Closed   NYPD    564
# 15    Closed    HRA     20
# 14    Closed    HPD     66
# 12    Closed   DSNY      4
# 11    Closed    DPR     71
# 10    Closed    DOT    118
# 9     Closed  DOITT      1
# 8     Closed  DOHMH     28
# 7     Closed    DOF      6
# 6     Closed    DOE      2
# 5     Closed    DOB     16
# 4     Closed    DCA     33
# 3     Closed  3-1-1      1
# 1   Assigned    DPR      8
# 2   Assigned    TLC      1
# 0   Assigned  DOHMH      1

# %% [markdown]
# # Query 4: Output should contain-
# # Column 1: List of agencies.
# # Column 2: Which complaint type does it receive most frequently.
# # Column 3: What is the average time it's taking to solve it.

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)

dataframe2['Created Date'] = pd.to_datetime(dataframe2['Created Date'])
dataframe2['Closed Date'] = pd.to_datetime(dataframe2['Closed Date'])



dataframe2['Time'] = dataframe2['Closed Date'] - dataframe2['Created Date']


datafr = dataframe2[dataframe2['Agency'].notnull() & dataframe2['Status'].notnull()]

dataframe4 = datafr[['Agency', 'Created Date','Status', 'Complaint Type','Borough']].groupby(['Agency', 'Complaint Type'])["Complaint Type"].count().reset_index(name="count").sort_values(by='count', ascending=0)
dataframe4 = dataframe4.reset_index(drop=True)


#get the complaint type
complaint = dataframe4.ix[0,'Complaint Type']
count = dataframe4.ix[0,'count']
print(complaint, '-', count)

dataframe5 = dataframe2[(dataframe['Complaint Type'] == complaint)] 



average_time = dataframe5['Time'].mean()
print('Average Time: ', average_time)
dataframe5[['Agency', 'Borough','Status','Time']].sort_values(by='Status', ascending=0)
# Out:
# Blocked Driveway - 153
# Average Time:  0 days 03:57:22.535947
#     Agency        Borough  Status     Time
# 2     NYPD          BRONX  Closed 04:13:48
# 723   NYPD         QUEENS  Closed 01:23:44
# 697   NYPD          BRONX  Closed 08:11:07
# 699   NYPD         QUEENS  Closed 06:10:09
# 700   NYPD         QUEENS  Closed 01:08:11
# 706   NYPD         QUEENS  Closed 08:56:36
# 710   NYPD         QUEENS  Closed 01:35:05
# 716   NYPD       BROOKLYN  Closed 02:08:21
# 722   NYPD  STATEN ISLAND  Closed 02:36:12
# 728   NYPD         QUEENS  Closed 04:40:43
# 564   NYPD       BROOKLYN  Closed 01:25:12
# 746   NYPD         QUEENS  Closed 03:59:49
# 747   NYPD       BROOKLYN  Closed 01:27:34
# 748   NYPD       BROOKLYN  Closed 01:31:27
# 755   NYPD       BROOKLYN  Closed 01:34:59
# 760   NYPD       BROOKLYN  Closed 02:49:08
# 763   NYPD       BROOKLYN  Closed 00:28:48
# 766   NYPD       BROOKLYN  Closed 01:47:36
# 689   NYPD          BRONX  Closed 02:33:29
# ...

# %% [markdown]
# # Query 1: Output should contain-
# # Column 1: List of cities ordered by highest number of complaints to lowest.
# # Column 2: Highest recorded 'complaint type' against its respective city.
# # Column 3: What percentage does each highest complaint occupy among it's total number of complaints.

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)


dataframe2['Created Date'] = pd.to_datetime(dataframe2['Created Date'])
dataframe2['Closed Date'] = pd.to_datetime(dataframe2['Closed Date'])
dataframe2['Time'] = dataframe2['Closed Date'] - dataframe2['Created Date']

dataframe5 = dataframe2.groupby(['Agency', 'Borough'])["Complaint Type"].count().reset_index(name="count").sort_values(by='count', ascending=0)
dataframe5
# Out:
#    Agency        Borough  count
# 45   NYPD       BROOKLYN    206
# 47   NYPD         QUEENS    126
# 46   NYPD      MANHATTAN    122
# 44   NYPD          BRONX     88
# 30    DPR         QUEENS     38
# 24    DOT         QUEENS     38
# 22    DOT       BROOKLYN     29
# 38    HPD          BRONX     24
# 28    DPR       BROOKLYN     22
# 23    DOT      MANHATTAN     22
# 48   NYPD  STATEN ISLAND     21
# 21    DOT          BRONX     20
# 43    HRA    Unspecified     20
# 40    HPD      MANHATTAN     18
# 17  DOHMH      MANHATTAN     16
# 39    HPD       BROOKLYN     15
# 8     DOB         QUEENS     15
# 29    DPR      MANHATTAN     12
# 4     DCA         QUEENS     11
# 31    DPR  STATEN ISLAND     11
# 52    TLC      MANHATTAN     10
# 16  DOHMH       BROOKLYN     10
# 27    DPR          BRONX      9
# 18  DOHMH         QUEENS      9
# 1     DCA          BRONX      8
# 15  DOHMH          BRONX      8
# 25    DOT  STATEN ISLAND      8
# 41    HPD         QUEENS      8
# ...

# %% [markdown]
# # Query 1: Output should contain-
# # Column 1: List of cities ordered by highest number of complaints to lowest.
# # Column 2: Highest recorded 'complaint type' against its respective city.
# # Column 3: What percentage does each highest complaint occupy among it's total number of complaints.

# %%
dataframe = pd.read_csv('F:/Python_Project/1000linesfile.csv')
dataframe2 = dataframe.drop(['School Not Found','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name','Location','Latitude','Longitude'],axis=1)


dataframe2['Created Date'] = pd.to_datetime(dataframe2['Created Date'])
dataframe2['Closed Date'] = pd.to_datetime(dataframe2['Closed Date'])
dataframe2['Time'] = dataframe2['Closed Date'] - dataframe2['Created Date']

dataframe5 = dataframe2.groupby(['Complaint Type', 'Borough'])["Complaint Type"].count().reset_index(name="count").sort_values(by='count', ascending=0)
dataframe5 = dataframe5.reset_index(drop=True)
total_complaints = dataframe5['count'].sum()
dataframe5['Percentage'] = dataframe5['count'] / total_complaints
dataframe5

dataframe5.groupby('Complaint Type').sum().sort_values(by='count', ascending=0)
# Out:
#                                            count  Percentage
# Complaint Type
# Blocked Driveway                             153    0.153153
# Illegal Parking                              142    0.142142
# Noise - Street/Sidewalk                       94    0.094094
# Street Condition                              69    0.069069
# Noise - Commercial                            62    0.062062
# Consumer Complaint                            32    0.032032
# Noise - Vehicle                               24    0.024024
# Derelict Vehicle                              22    0.022022
# Damaged Tree                                  21    0.021021
# Benefit Card Replacement                      20    0.020020
# Broken Muni Meter                             19    0.019019
# Maintenance or Facility                       18    0.018018
# Dead Tree                                     18    0.018018
# Overgrown Tree/Branches                       16    0.016016
# ...
